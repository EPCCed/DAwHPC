# %% [markdown]
# # Data Analytics with High Performance Computing - Practical 2
# ## Data Cleaning in Parallel with Dask

# %% [markdown]
# ### Learning outcomes

# %% [markdown]
# Practice some common techniques for data cleaning with Python, using functionality of the Pandas library.
# *  Part 1 - (Practical2a.ipynb) reading data, data exploration, data typing, coercion.
# *  Part 2 - (Practical2b.ipynb) dealing with unstructured data, pattern matching, regular expressions, handling missing data, more typing and coercion, standardisation.

# %% [markdown]
# ### 1. Reading and cleaning data

# %% [markdown]
# Import Pandas and NumPy<br/>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Import Dask dataframe

# %%
from dask import dataframe as dd

# %% [markdown]
# Other imports

# %%
# %matplotlib inline
from matplotlib.pyplot import imshow

# %% [markdown]
# #### Import and run a Dask Client
# This runs a Dask Dashboard, which provides a visualisation of computations run by Dask. Running the cell below will start the client and produce a link that you can open for viewing during the practical.<br/>
# Note: the use of the Dask Client is optional and carries its own CPU overhead, but is useful here for extra insight.

# %%
from dask.distributed import Client

client = Client(n_workers=36, threads_per_worker=2, memory_limit="12GB")
client
# Out:
# <Client: 'tcp://127.0.0.1:42105' processes=36 threads=72, memory=402.33 GiB>

# %% [markdown]
# Have a browse of the dashboard and familiarise yourself with the kinds of data it displays. To being with this will look like the image below.
# * The top left panel shows the total memory usage
# * Below that we have the memory usage per worker (we are using 2 workers)
# * At the bottom left you can cycle through plots for "Processing", "CPU", "Occupancy" and "Data Transfer".
# * The large plots on the left will show the Dask task queue (top) and the "Progress" (bottom).
#
# <img src="/work/m22oc/m22oc/shared/DAwHPC/practicals_data/P3/P3SS1.png" alt="Dask Dashboard" width="1024"/><br/>
# Fig. 1 - Dask Dashboard start screen.

# %%
df = dd.read_csv('/work/m22oc/m22oc/shared/DAwHPC/practicals_data/P3/*2019.csv')

# %%
df
# Out:
# Dask DataFrame Structure:
#                DATE_TIME SITE_ID     LWIN    LWOUT     SWIN    SWOUT       RN   PRECIP       PA       TA       WS       WD        Q       RH SNOWD_DISTANCE_COR     UX     UY     UZ       G1       G2 TDT1_TSOIL TDT1_VWC TDT2_TSOIL TDT2_VWC TDT3_TSOIL TDT3_VWC TDT4_TSOIL TDT4_VWC TDT5_TSOIL TDT5_VWC TDT6_TSOIL TDT6_VWC TDT7_TSOIL TDT7_VWC TDT8_TSOIL TDT8_VWC TDT9_TSOIL TDT9_VWC TDT10_TSOIL TDT10_VWC STP_TSOIL2 STP_TSOIL5 STP_TSOIL10 STP_TSOIL20 STP_TSOIL50
# npartitions=51
#                   object  object  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64              int64  int64  int64  int64  float64  float64    float64  float64      int64    int64      int64    int64      int64    int64      int64    int64      int64    int64      int64    int64      int64    int64      int64    int64       int64     int64    float64    float64     float64     float64     float64
#                      ...     ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...                ...    ...    ...    ...      ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...         ...       ...        ...        ...         ...         ...         ...
# ...                  ...     ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...                ...    ...    ...    ...      ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...         ...       ...        ...        ...         ...         ...         ...
#                      ...     ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...                ...    ...    ...    ...      ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...         ...       ...        ...        ...         ...         ...         ...
#                      ...     ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...                ...    ...    ...    ...      ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...         ...       ...        ...        ...         ...         ...         ...
# Dask Name: read-csv, 1 graph layer

# %%
df.visualize()
# hint: double click the image to zoom in

# %% [markdown]
# As shown in the task graph above, the Dask dataframe is divided up (partitioned) into 51 Pandas DataFrame objects (1 per CSV file). These will be read in through 51 parallel calls to dataframe.read_csv(). We'll leave it like that for now.

# %% [markdown]
# So, the DATE_TIME column is a date, the "SITE_ID" column is a string, and all of the measured data are floats.
# We are also told there will be data missing for some sites as not all sites have all intrument types, and not all sites came online on the same starting date. Missing data have the value `-9999`.
# This is clearly inconsistent - data that are present are floats and missing data are integers!

# %% [markdown]
# Let's say we want to study the soil surface temperature (mean of TDT1_TSOIL and TDT2_TSOIL) over time at all sites.

# %% [markdown]
# Instantiating a Dask dataframe does not load the data, but constructs arrays ready to receive the data. We can see the column names and the data types.<br>
# First, let's store the "DATE_TIME" column as a datetime64 object, rather than a general object.<br>
# Remember, the DASK API build on the Pandas API, where you may have come across the to_datetime() function.

# %%
df['DATE_TIME'] = dd.to_datetime(df['DATE_TIME'])
df
# Out:
# Dask DataFrame Structure:
#                      DATE_TIME SITE_ID     LWIN    LWOUT     SWIN    SWOUT       RN   PRECIP       PA       TA       WS       WD        Q       RH SNOWD_DISTANCE_COR     UX     UY     UZ       G1       G2 TDT1_TSOIL TDT1_VWC TDT2_TSOIL TDT2_VWC TDT3_TSOIL TDT3_VWC TDT4_TSOIL TDT4_VWC TDT5_TSOIL TDT5_VWC TDT6_TSOIL TDT6_VWC TDT7_TSOIL TDT7_VWC TDT8_TSOIL TDT8_VWC TDT9_TSOIL TDT9_VWC TDT10_TSOIL TDT10_VWC STP_TSOIL2 STP_TSOIL5 STP_TSOIL10 STP_TSOIL20 STP_TSOIL50
# npartitions=51
#                 datetime64[ns]  object  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64              int64  int64  int64  int64  float64  float64    float64  float64      int64    int64      int64    int64      int64    int64      int64    int64      int64    int64      int64    int64      int64    int64      int64    int64       int64     int64    float64    float64     float64     float64     float64
#                            ...     ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...                ...    ...    ...    ...      ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...         ...       ...        ...        ...         ...         ...         ...
# ...                        ...     ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...                ...    ...    ...    ...      ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...         ...       ...        ...        ...         ...         ...         ...
#                            ...     ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...                ...    ...    ...    ...      ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...         ...       ...        ...        ...         ...         ...         ...
#                            ...     ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...                ...    ...    ...    ...      ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...        ...      ...         ...       ...        ...        ...         ...         ...         ...
# Dask Name: assign, 4 graph layers

# %%
df.visualize()

# %% [markdown]
# We can now see a more complex task graph for each of the 51 objects being generated in parallel - now the coercion of the data columns is being done in parallel to the file being read.

# %% [markdown]
# Looking along the row of data types, there are a number of columns with `int64` data. Any attempts to view the data will result in compute errors due to this inconsistent data typing.
# For example, `df.head()`:

# %%
try:
    df.head() # intentionally fails
except ValueError as ve:
    print(ve)
# Out:
# Mismatched dtypes found in `pd.read_csv`/`pd.read_table`.
#
# +--------------------+---------+----------+
# | Column             | Found   | Expected |
# +--------------------+---------+----------+
# | SNOWD_DISTANCE_COR | float64 | int64    |
# | TDT2_TSOIL         | float64 | int64    |
# | TDT2_VWC           | float64 | int64    |
# +--------------------+---------+----------+
#
# Usually this is due to dask's dtype inference failing, and
# *may* be fixed by specifying dtypes manually by adding:
#
# dtype={'SNOWD_DISTANCE_COR': 'float64',
#        'TDT2_TSOIL': 'float64',
#        'TDT2_VWC': 'float64'}
#
# to the call to `read_csv`/`read_table`.
#
# Alternatively, provide `assume_missing=True` to interpret
# all unspecified integer columns as floats.
# 2022-10-05 14:23:16,915 - distributed.worker - WARNING - Compute Failed
# Key:       ('assign-a72072af236b27f2ecfacc890d8b8602', 0)
# Function:  execute_task
# args:      ((subgraph_callable-310382b3-6138-4138-a859-ed753b417ab7, [(<function read_block_from_file at 0x146655d64040>, <OpenFile '/work/m22oc/m22oc/shared/DAwHPC/practicals_data/P3/COSMOS-UK_ALIC1_HydroSoil_SH_2013-2019.csv'>, 0, 24157118, b'\n'), None, True, True]))
# kwargs:    {}
# Exception: 'ValueError("Mismatched dtypes found in `pd.read_csv`/`pd.read_table`.\\n\\n+--------------------+---------+----------+\\n| Column             | Found   | Expected |\\n+--------------------+---------+----------+\\n| SNOWD_DISTANCE_COR | float64 | int64    |\\n| TDT2_TSOIL         | float64 | int64    |\\n| TDT2_VWC           | float64 | int64    |\\n+--------------------+---------+----------+\\n\\nUsually this is due to dask\'s dtype inference failing, and\\n*may* be fixed by specifying dtypes manually by adding:\\n\\ndtype={\'SNOWD_DISTANCE_COR\': \'float64\',\\n       \'TDT2_TSOIL\': \'float64\',\\n       \'TDT2_VWC\': \'float64\'}\\n\\nto the call to `read_csv`/`read_table`.\\n\\nAlternatively, provide `assume_missing=True` to interpret\\nall unspecified integer columns as floats.")'

# %% [markdown]
# This fails because the data types in some of the columns are inconsistent. Three columns, 'SNOWD_DISTANCE_COR', 'TDT2_TSOIL' and 'TDT2_VWC' are mentioned, but there may be more.<br>
# Dask reports "expected" data types for these are `int64`, but `float64` values are found.

# %% [markdown]
# Let's take a step back and look at the metadata.

# %%
metadata = pd.read_csv('/work/m22oc/m22oc/shared/DAwHPC/practicals_data/P3/COSMOS-UK_HydroSoil_SH_2013-2019_Metadata.csv')
metadata
# Out:
#            VARIABLE_ID                   VARIABLE_NAME RESOLUTION  \
# 0                   G1                Soil heat flux 1  30 Minute
# 1                   G2                Soil heat flux 2  30 Minute
# 2                 LWIN     Incoming longwave radiation  30 Minute
# 3                LWOUT     Outgoing longwave radiation  30 Minute
# 4                   PA            Atmospheric pressure  30 Minute
# 5               PRECIP                   Precipitation  30 Minute
# 6                    Q               Absolute humidity  30 Minute
# 7                   RH               Relative humidity  30 Minute
# 8                   RN                   Net radiation  30 Minute
# 9   SNOWD_DISTANCE_COR                      Snow depth  30 Minute
# 10         STP_TSOIL10  Soil temperature at depth 10cm  30 Minute
# 11          STP_TSOIL2   Soil temperature at depth 2cm  30 Minute
# 12         STP_TSOIL20  Soil temperature at depth 20cm  30 Minute
# 13          STP_TSOIL5   Soil temperature at depth 5cm  30 Minute
# 14         STP_TSOIL50  Soil temperature at depth 50cm  30 Minute
# 15                SWIN    Incoming shortwave radiation  30 Minute
# 16               SWOUT    Outgoing shortwave radiation  30 Minute
# 17                  TA                 Air temperature  30 Minute
# 18          TDT1_TSOIL  Soil temperature at depth 10cm  30 Minute
# 19            TDT1_VWC     Soil moisture at depth 10cm  30 Minute
# 20         TDT10_TSOIL  Soil temperature at depth 50cm  30 Minute
# 21           TDT10_VWC     Soil moisture at depth 50cm  30 Minute
# 22          TDT2_TSOIL  Soil temperature at depth 10cm  30 Minute
# 23            TDT2_VWC     Soil moisture at depth 10cm  30 Minute
# 24          TDT3_TSOIL   Soil temperature at depth 5cm  30 Minute
# 25            TDT3_VWC      Soil moisture at depth 5cm  30 Minute
# 26          TDT4_TSOIL   Soil temperature at depth 5cm  30 Minute
# 27            TDT4_VWC      Soil moisture at depth 5cm  30 Minute
# 28          TDT5_TSOIL  Soil temperature at depth 15cm  30 Minute
# 29            TDT5_VWC     Soil moisture at depth 15cm  30 Minute
# 30          TDT6_TSOIL  Soil temperature at depth 15cm  30 Minute
# 31            TDT6_VWC     Soil moisture at depth 15cm  30 Minute
# 32          TDT7_TSOIL  Soil temperature at depth 25cm  30 Minute
# 33            TDT7_VWC     Soil moisture at depth 25cm  30 Minute
# 34          TDT8_TSOIL  Soil temperature at depth 25cm  30 Minute
# 35            TDT8_VWC     Soil moisture at depth 25cm  30 Minute
# 36          TDT9_TSOIL  Soil temperature at depth 50cm  30 Minute
# 37            TDT9_VWC     Soil moisture at depth 50cm  30 Minute
# 38                  UX      X component of wind speend  30 Minute
# 39                  UY      Y component of wind speend  30 Minute
# 40                  UZ      Z component of wind speend  30 Minute
# 41                  WD                  Wind direction  30 Minute
# 42                  WS                      Wind speed  30 Minute
#
#            UNIT                   AGGREGATION       DATA_TYPE  MISSING_VALUE
# 0          Wm-2   Mean over preceding 30 mins  Floating Point          -9999
# 1          Wm-2   Mean over preceding 30 mins  Floating Point          -9999
# 2          Wm-2   Mean over preceding 30 mins  Floating Point          -9999
# 3          Wm-2   Mean over preceding 30 mins  Floating Point          -9999
# 4           hPa   Mean over preceding 30 mins  Floating Point          -9999
# 5            mm  Total over preceding 30 mins  Floating Point          -9999
# 6          gm-3   Mean over preceding 30 mins  Floating Point          -9999
# 7             %   Mean over preceding 30 mins  Floating Point          -9999
# 8          Wm-2   Mean over preceding 30 mins  Floating Point          -9999
# 9            mm                 Instantaneous  Floating Point          -9999
# 10  Deg Celsius   Mean over preceding 30 mins  Floating Point          -9999
# 11  Deg Celsius   Mean over preceding 30 mins  Floating Point          -9999
# 12  Deg Celsius   Mean over preceding 30 mins  Floating Point          -9999
# 13  Deg Celsius   Mean over preceding 30 mins  Floating Point          -9999
# 14  Deg Celsius   Mean over preceding 30 mins  Floating Point          -9999
# 15         Wm-2   Mean over preceding 30 mins  Floating Point          -9999
# 16         Wm-2   Mean over preceding 30 mins  Floating Point          -9999
# 17  Deg Celsius   Mean over preceding 30 mins  Floating Point          -9999
# 18  Deg Celsius                 Instantaneous  Floating Point          -9999
# 19            %                 Instantaneous  Floating Point          -9999
# 20  Deg Celsius                 Instantaneous  Floating Point          -9999
# 21            %                 Instantaneous  Floating Point          -9999
# 22  Deg Celsius                 Instantaneous  Floating Point          -9999
# 23            %                 Instantaneous  Floating Point          -9999
# 24  Deg Celsius                 Instantaneous  Floating Point          -9999
# 25            %                 Instantaneous  Floating Point          -9999
# 26  Deg Celsius                 Instantaneous  Floating Point          -9999
# 27            %                 Instantaneous  Floating Point          -9999
# 28  Deg Celsius                 Instantaneous  Floating Point          -9999
# 29            %                 Instantaneous  Floating Point          -9999
# 30  Deg Celsius                 Instantaneous  Floating Point          -9999
# 31            %                 Instantaneous  Floating Point          -9999
# 32  Deg Celsius                 Instantaneous  Floating Point          -9999
# 33            %                 Instantaneous  Floating Point          -9999
# 34  Deg Celsius                 Instantaneous  Floating Point          -9999
# 35            %                 Instantaneous  Floating Point          -9999
# 36  Deg Celsius                 Instantaneous  Floating Point          -9999
# 37            %                 Instantaneous  Floating Point          -9999
# 38         ms-1   Mean over preceding 30 mins  Floating Point          -9999
# 39         ms-1   Mean over preceding 30 mins  Floating Point          -9999
# 40         ms-1   Mean over preceding 30 mins  Floating Point          -9999
# 41      Degrees   Mean over preceding 30 mins  Floating Point          -9999
# 42         ms-1   Mean over preceding 30 mins  Floating Point          -9999

# %% [markdown]
# So, the DATE_TIME column is a formatted date string, the "SITE_ID" column is a string, and all of the measured data are floats.<br>
# We are also told (separately) there will be data missing for some sites as not all sites have all intrument types, and not all sites came online on the same starting date.<br>
# Missing data have the value `-9999`.<br>
# This is clearly inconsistent - data that are present are floats and missing data are integers!

# %% [markdown]
# Now take a look at a data file:

# %%
# !head /work/m22oc/m22oc/shared/DAwHPC/practicals_data/P3/COSMOS-UK_ALIC1_HydroSoil_SH_2013-2019.csv
# Out:
# DATE_TIME,SITE_ID,LWIN,LWOUT,SWIN,SWOUT,RN,PRECIP,PA,TA,WS,WD,Q,RH,SNOWD_DISTANCE_COR,UX,UY,UZ,G1,G2,TDT1_TSOIL,TDT1_VWC,TDT2_TSOIL,TDT2_VWC,TDT3_TSOIL,TDT3_VWC,TDT4_TSOIL,TDT4_VWC,TDT5_TSOIL,TDT5_VWC,TDT6_TSOIL,TDT6_VWC,TDT7_TSOIL,TDT7_VWC,TDT8_TSOIL,TDT8_VWC,TDT9_TSOIL,TDT9_VWC,TDT10_TSOIL,TDT10_VWC,STP_TSOIL2,STP_TSOIL5,STP_TSOIL10,STP_TSOIL20,STP_TSOIL50
# 2015-03-06T13:30:00Z,ALIC1,278.4,371.9,521.5,62.95,365.05,-9999,-9999,10.19,3.62,210.7,5.793,60.93,-9999,-9999,-9999,-9999,40.617,45.8,5.89,19.44,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,7.903,6.673,5.761,5.127,5.474
# 2015-03-06T14:00:00Z,ALIC1,275.9,373.0,526.0,63.06,365.84,0.0,1020.0,10.43,4.329,211.5,5.858,60.69,-9999,-9999,-9999,-9999,33.512,43.042,6.06,19.51,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,7.987,6.823,5.893,5.165,5.491
# 2015-03-06T14:30:00Z,ALIC1,275.5,373.0,489.8,58.98,333.32,0.0,1019.0,10.61,3.951,214.4,5.655,57.92,-9999,-9999,-9999,-9999,32.651,37.422,6.23,19.56,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,7.929,6.951,6.039,5.193,5.483
# 2015-03-06T15:00:00Z,ALIC1,273.8,371.6,428.0,51.53,278.67,0.0,1019.0,10.69,3.67,213.0,5.62,57.27,-9999,-9999,-9999,-9999,26.239,31.011,6.37,19.67,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,7.863,7.014,6.174,5.25,5.494
# 2015-03-06T15:30:00Z,ALIC1,271.9,367.6,344.1,41.47,206.93,0.0,1019.0,10.39,4.18,212.7,5.277,54.81,-9999,-9999,-9999,-9999,21.459,26.853,6.46,19.8,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,7.809,7.045,6.257,5.29,5.483
# 2015-03-06T16:00:00Z,ALIC1,270.7,365.0,275.8,35.3,146.2,0.0,1019.0,10.24,3.98,210.1,5.143,53.92,-9999,-9999,-9999,-9999,13.851,18.91,6.53,19.85,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,7.594,7.037,6.337,5.341,5.489
# 2015-03-06T16:30:00Z,ALIC1,268.3,361.6,205.4,29.89,82.21,0.0,1018.0,9.98,3.966,209.9,4.913,52.37,-9999,-9999,-9999,-9999,8.351,13.059,6.58,19.85,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,7.355,6.963,6.372,5.386,5.484
# 2015-03-06T17:00:00Z,ALIC1,267.3,357.6,117.5,19.11,8.09,0.0,1018.0,9.52,3.623,197.1,5.234,57.45,-9999,-9999,-9999,-9999,3.525,7.699,6.58,19.97,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,7.092,6.866,6.392,5.446,5.493
# 2015-03-06T17:30:00Z,ALIC1,264.6,352.0,56.06,10.35,-41.69,0.0,1017.0,8.64,3.943,191.8,5.656,65.67,-9999,-9999,-9999,-9999,-0.451,2.971,6.58,19.97,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,-9999,6.812,6.73,6.37,5.488,5.489

# %% [markdown]
# The first file alphabetically has `-9999` values in the columns reported in the Dask error - we need to fix these!<br>
# Dask has used the first row of data from the first CSV file to define data types for each column - the error arises when it finds a row of data that does not conform to expected data types.

# %% [markdown]
# Let's load the data again, but this time deal with missing data, coerce data types, and ignore columns of data we don't need.

# %%
# a list of the columns we are interested in - we'll look at the air temperature and the soil temperature closest to the surface
cols = ['DATE_TIME','SITE_ID','TA','TDT1_TSOIL','TDT2_TSOIL']
dtypes = {'DATE_TIME':object,'SITE_ID':str,'TA':np.float64,'TDT1_TSOIL':np.float64,'TDT2_TSOIL':np.float64}
# Note: we read "DATE_TIME" as a general object, but pass this column to the "parse_dates" option.
df = dd.read_csv('/work/m22oc/m22oc/shared/DAwHPC/practicals_data/P3/*2019.csv', usecols=cols, dtype=dtypes, parse_dates=['DATE_TIME']).replace(-9999,np.nan)
df
# Out:
# Dask DataFrame Structure:
#                           DATE_TIME SITE_ID       TA TDT1_TSOIL TDT2_TSOIL
# npartitions=51
#                 datetime64[ns, UTC]  object  float64    float64    float64
#                                 ...     ...      ...        ...        ...
# ...                             ...     ...      ...        ...        ...
#                                 ...     ...      ...        ...        ...
#                                 ...     ...      ...        ...        ...
# Dask Name: replace, 2 graph layers

# %%
df.visualize()

# %% [markdown]
# What, if anything, is different about this task graph?

# %% [markdown]
# Now we can view the first few rows of the Dask dataframe. Check the Dask Dashboard for activity.

# %%
# %time df.head()
# Out:
# CPU times: user 169 ms, sys: 42.3 ms, total: 212 ms
# Wall time: 525 ms
#                   DATE_TIME SITE_ID     TA  TDT1_TSOIL  TDT2_TSOIL
# 0 2015-03-06 13:30:00+00:00   ALIC1  10.19        5.89         NaN
# 1 2015-03-06 14:00:00+00:00   ALIC1  10.43        6.06         NaN
# 2 2015-03-06 14:30:00+00:00   ALIC1  10.61        6.23         NaN
# 3 2015-03-06 15:00:00+00:00   ALIC1  10.69        6.37         NaN
# 4 2015-03-06 15:30:00+00:00   ALIC1  10.39        6.46         NaN

# %% [markdown]
# We will now perform a simple task of viewing the temperature trend at each site over the lifetime of the data. SInce this is a timeseries type operation, it will be more efficient if we set the index of the dataframe to the "DATE_TIME" column.

# %%
# %time df.set_index('DATE_TIME')
# Out:
# CPU times: user 1.01 s, sys: 182 ms, total: 1.19 s
# Wall time: 1.43 s
# Dask DataFrame Structure:
#                           SITE_ID       TA TDT1_TSOIL TDT2_TSOIL
# npartitions=51
# 2013-10-02 13:30:00+00:00  object  float64    float64    float64
# 2014-07-25 08:00:00+00:00     ...      ...        ...        ...
# ...                           ...      ...        ...        ...
# 2019-12-09 02:30:00+00:00     ...      ...        ...        ...
# 2020-01-01 00:00:00+00:00     ...      ...        ...        ...
# Dask Name: sort_index, 9 graph layers

# %%
# %time df.head()
# Out:
# CPU times: user 212 ms, sys: 51.6 ms, total: 264 ms
# Wall time: 586 ms
#                   DATE_TIME SITE_ID     TA  TDT1_TSOIL  TDT2_TSOIL
# 0 2015-03-06 13:30:00+00:00   ALIC1  10.19        5.89         NaN
# 1 2015-03-06 14:00:00+00:00   ALIC1  10.43        6.06         NaN
# 2 2015-03-06 14:30:00+00:00   ALIC1  10.61        6.23         NaN
# 3 2015-03-06 15:00:00+00:00   ALIC1  10.69        6.37         NaN
# 4 2015-03-06 15:30:00+00:00   ALIC1  10.39        6.46         NaN

# %% [markdown]
# We can now, very quickly, view run groupby() commands.
# Here we group by 'SITE_ID' and show the 'ALIC1' group.

# %%
# %time df.groupby('SITE_ID').get_group('ALIC1').compute()
# Out:
# CPU times: user 711 ms, sys: 204 ms, total: 915 ms
# Wall time: 1.55 s
#                       DATE_TIME SITE_ID      TA  TDT1_TSOIL  TDT2_TSOIL
# 0     2015-03-06 13:30:00+00:00   ALIC1  10.190        5.89         NaN
# 1     2015-03-06 14:00:00+00:00   ALIC1  10.430        6.06         NaN
# 2     2015-03-06 14:30:00+00:00   ALIC1  10.610        6.23         NaN
# 3     2015-03-06 15:00:00+00:00   ALIC1  10.690        6.37         NaN
# 4     2015-03-06 15:30:00+00:00   ALIC1  10.390        6.46         NaN
# ...                         ...     ...     ...         ...         ...
# 84545 2019-12-31 22:00:00+00:00   ALIC1   6.203        6.89        6.73
# 84546 2019-12-31 22:30:00+00:00   ALIC1   6.051        6.87        6.72
# 84547 2019-12-31 23:00:00+00:00   ALIC1   5.881        6.84        6.70
# 84548 2019-12-31 23:30:00+00:00   ALIC1   5.738        6.82        6.70
# 84549 2020-01-01 00:00:00+00:00   ALIC1   5.663        6.82        6.68
#
# [84550 rows x 5 columns]

# %% [markdown]
# In the above, note the .compute() call at the end of the line.<br>
# Without .compute(), the task graph is generated, but not computed.

# %%
alic1 = df.groupby('SITE_ID').get_group('ALIC1')
alic1.visualize()

# %%
alic1.compute()
# Out:
#                       DATE_TIME SITE_ID      TA  TDT1_TSOIL  TDT2_TSOIL
# 0     2015-03-06 13:30:00+00:00   ALIC1  10.190        5.89         NaN
# 1     2015-03-06 14:00:00+00:00   ALIC1  10.430        6.06         NaN
# 2     2015-03-06 14:30:00+00:00   ALIC1  10.610        6.23         NaN
# 3     2015-03-06 15:00:00+00:00   ALIC1  10.690        6.37         NaN
# 4     2015-03-06 15:30:00+00:00   ALIC1  10.390        6.46         NaN
# ...                         ...     ...     ...         ...         ...
# 84545 2019-12-31 22:00:00+00:00   ALIC1   6.203        6.89        6.73
# 84546 2019-12-31 22:30:00+00:00   ALIC1   6.051        6.87        6.72
# 84547 2019-12-31 23:00:00+00:00   ALIC1   5.881        6.84        6.70
# 84548 2019-12-31 23:30:00+00:00   ALIC1   5.738        6.82        6.70
# 84549 2020-01-01 00:00:00+00:00   ALIC1   5.663        6.82        6.68
#
# [84550 rows x 5 columns]

# %% [markdown]
# The each time the Dask operations are computed, the data is being read from file.<br>
# This is great if the files being analysed are too large for the available memory.<br>
# However, if we do have enough memory, analysis will be a lot faster if the data is kept in memory!

# %%
df2 = df.persist()
df2.visualize()

# %% [markdown]
# Note the calls to read_csv() are gone and, once computed, `df2` will be represented as 51 Pandas DataFrames in memory.

# %%
# %time df2.groupby('SITE_ID')['TA'].mean().compute()
#Group by SITE_ID and compute the average air temperature
#Run this cell twice and observe the difference
#Depending on the filesystem, this may be orders of magnitude faster.
# Out:
# CPU times: user 172 ms, sys: 24.4 ms, total: 197 ms
# Wall time: 196 ms
# SITE_ID
# ALIC1    10.927174
# BALRD     8.880826
# BICKL    10.048129
# BUNNY    10.628194
# CARDT    11.181747
# CGARW     9.691159
# CHIMN    10.443856
# CHOBH    10.635571
# COCHN     8.303823
# COCLP     8.848499
# CRICH     9.182283
# EASTB     8.381680
# ELMST    10.647160
# EUSTN    10.907918
# FINCH    11.172987
# FIVET     9.393436
# GISBN     8.329593
# GLENS     6.623934
# GLENW     8.332434
# HADLW    10.720809
# HARTW     8.358973
# HARWD     7.902479
# HENFS     9.631647
# HILLB     9.554486
# HLACY    11.543561
# HOLLN     9.924608
# HYBRY    10.058990
# LIZRD    11.140881
# LODTN    10.261159
# LULLN    10.959323
# MOORH     6.985737
# MOREM    10.020592
# MORLY    10.680815
# NWYKE    10.282385
# PLYNL     7.285601
# PORTN    10.498931
# RDMER    11.028771
# REDHL    10.923675
# RISEH    10.676650
# ROTHD    10.583686
# SHEEP     9.911862
# SOURH     8.041314
# SPENF     9.969199
# STGHT    10.242394
# STIPS     7.924171
# SYDLG     9.746100
# TADHM    10.774289
# WADDN    10.557415
# WIMPL     8.828801
# WRTTL    11.255351
# WYTH1    10.458253
# Name: TA, dtype: float64

# %%
# %time df2.groupby('DATE_TIME').mean().compute().plot() # this is quite slow and the resulting plot is not all that useful!
# Out:
# CPU times: user 5.26 s, sys: 209 ms, total: 5.47 s
# Wall time: 5.96 s
# <AxesSubplot: xlabel='DATE_TIME'>

# %% [markdown]
# Wow, that's a lot of data! Maybe a bit too much. This shows the seasonal temperature changes in the UK.<br>
# Let's combine the soil temperature columns by averaging them, and change our cadence (sampling) to 1 day.

# %%
df3['SOIL_TEMP'] = df3[['TDT1_TSOIL','TDT2_TSOIL']].mean(axis=1)
df3 = df3.drop(columns=['TDT1_TSOIL','TDT2_TSOIL'])
df3
# Out:
# Dask DataFrame Structure:
#                           DATE_TIME SITE_ID       TA SOIL_TEMP
# npartitions=51
#                 datetime64[ns, UTC]  object  float64   float64
#                                 ...     ...      ...       ...
# ...                             ...     ...      ...       ...
#                                 ...     ...      ...       ...
#                                 ...     ...      ...       ...
# Dask Name: drop_by_shallow_copy, 5 graph layers

# %%
# %time df3.groupby('DATE_TIME').mean().compute().plot()
# Out:
# CPU times: user 3.15 s, sys: 131 ms, total: 3.29 s
# Wall time: 3.83 s
# <AxesSubplot:xlabel='DATE_TIME'>

# %%
# Currently we are dividing our data up by the number of inisital CSV files:
df3.npartitions
# Out:
# 51

# %%
df3.memory_usage_per_partition().compute()
# Out:
# 0     2705728
# 1     3158816
# 2     2762336
# 3     2764928
# 4     2536992
# 5     1967072
# 6     3504448
# 7     2721056
# 8     1320064
# 9     2866944
# 10    2850016
# 11    3020768
# 12    1900736
# 13    2104992
# 14    1440192
# 15     850112
# 16    3017632
# 17    3160512
# 18    1988320
# 19    1783424
# 20    3151168
# 21    2587552
# 22    2266464
# 23    1989728
# 24     967200
# 25    3237248
# 26    1332608
# 27    2920864
# 28    2065120
# 29    2828480
# 30    2847168
# 31     630720
# 32    3160928
# 33    2922592
# 34    2891648
# 35    2825728
# 36    2022944
# 37    2169504
# 38    2052768
# 39    3050144
# 40    3470592
# 41    2870432
# 42    1741344
# 43    2451200
# 44    2889952
# 45     612256
# 46    2925472
# 47    3453568
# 48     171584
# 49    1398784
# 50    1596608
# dtype: int64

# %%
# We can, instead, divide up the data by the frequency of measurements, which is hourly.
divisions = tuple(pd.date_range(start='2015', end='2020', freq='1h'))
df4 = df3.set_index('DATE_TIME', divisions=divisions)

# %%
df4.npartitions
# Out:
# 43824

# %% [markdown]
# This is _not_ a good idea. In Dask we want a large enough number of partitions that each fits comfortably in memory, but we don't want too many partitions as many operations will scale relative to this number.

# %%
df4 = df4.repartition(npartitions=df4.npartitions // 100)

# %%
df4.npartitions
# Out:
# 438

# %%
df4.head()
# Out:
# 2022-09-28 15:20:06,495 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2022-09-28 15:20:08,368 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2022-09-28 15:20:08,989 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2022-09-28 15:20:09,650 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 
- distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2022-09-28 15:22:21,280 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-09-28 15:22:24,908 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2022-09-28 15:22:26,169 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:46389
# Traceback (most recent call last):
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/tornado/iostream.py", line 867, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/tornado/iostream.py", line 1140, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/worker.py", line 2029, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/worker.py", line 2818, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/worker.py", line 2798, in _get_data
#     response = await send_recv(
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:38150 remote=tcp://127.0.0.1:46389>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2022-09-28 15:22:39,087 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2022-09-28 15:22:39,095 - distributed.worker_memory - WARNING - gc.collect() took 3.680s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2022-09-28 15:22:39,109 - distributed.worker_memory - WARNING - Worker is at 84% memory usage. Pausing worker.  Process memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:22:40,384 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:46389 -> tcp://127.0.0.1:40615
# Traceback (most recent call last):
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/tornado/iostream.py", line 867, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/tornado/iostream.py", line 1140, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/worker.py", line 1736, in get_data
#     response = await comm.read(deserializers=serializers)
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:46389 remote=tcp://127.0.0.1:38150>: TimeoutError: [Errno 110] Connection timed out
# 2022-09-28 15:22:42,078 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.59 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:22:43,778 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:22:43,782 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:22:50,006 - distributed.worker_memory - WARNING - Worker tcp://127.0.0.1:46389 (pid=1504) exceeded 95% memory budget. Restarting...
# 2022-09-28 15:22:50,149 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:46389
# Traceback (most recent call last):
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/tornado/iostream.py", line 867, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/tornado/iostream.py", line 1140, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/worker.py", line 2029, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/worker.py", line 2818, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/worker.py", line 2798, in _get_data
#     response = await send_recv(
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:38190 remote=tcp://127.0.0.1:46389>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2022-09-28 15:22:50,201 - distributed.nanny - WARNING - Restarting worker
# 2022-09-28 15:23:04,574 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-09-28 15:23:08,094 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-09-28 15:23:09,457 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.35 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:23:09,473 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.36 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:23:12,608 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.43 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:23:12,684 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.42 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:23:12,945 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-09-28 15:23:18,231 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-09-28 15:23:24,913 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-09-28 15:23:26,860 - distributed.worker_memory - WARNING - gc.collect() took 1.666s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2022-09-28 15:23:26,861 - distributed.worker_memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 1.52 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:23:26,863 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.52 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:23:26,888 - distributed.worker_memory - WARNING - Worker is at 77% memory usage. Resuming worker. Process memory: 1.44 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:23:26,897 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.44 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:23:32,448 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-09-28 15:23:37,320 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.38 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:23:44,569 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-09-28 15:23:55,292 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-09-28 15:23:55,292 - distributed.worker_memory - WARNING - gc.collect() took 1.589s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2022-09-28 15:23:55,292 - distributed.worker_memory - WARNING - Worker is at 87% memory usage. Pausing worker.  Process memory: 1.63 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:23:55,294 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.63 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:23:55,296 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.62 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:24:01,354 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-09-28 15:24:03,076 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-09-28 15:24:05,994 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 
- distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2022-09-28 15:25:07,590 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2022-09-28 15:25:11,360 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2022-09-28 15:25:12,667 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2022-09-28 15:25:15,618 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2022-09-28 15:25:29,848 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2022-09-28 15:25:32,158 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2022-09-28 15:25:35,574 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2022-09-28 15:25:39,390 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2022-09-28 15:25:43,355 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2022-09-28 15:25:47,464 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2022-09-28 15:25:57,576 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2022-09-28 15:26:05,682 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 df4.head()
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/dataframe/core.py:1263, in _Frame.head(self, n, npartitions, compute)
#    1261 # No need to warn if we're already looking at all partitions
#    1262 safe = npartitions != self.npartitions
# -> 1263 return self._head(n=n, npartitions=npartitions, compute=compute, safe=safe)
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/dataframe/core.py:1297, in _Frame._head(self, n, npartitions, compute, safe)
#    1292 result = new_dd_object(
#    1293     graph, name, self._meta, [self.divisions[0], self.divisions[npartitions]]
#    1294 )
#    1296 if compute:
# -> 1297     result = result.compute()
#    1298 return result
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/base.py:315, in DaskMethodsMixin.compute(self, **kwargs)
#     291 def compute(self, **kwargs):
#     292     """Compute this dask collection
#     293
#     294     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     313     dask.base.compute
#     314     """
# --> 315     (result,) = compute(self, traverse=False, **kwargs)
#     316     return result
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/base.py:600, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     597     keys.append(x.__dask_keys__())
#     598     postcomputes.append(x.__dask_postcompute__())
# --> 600 results = schedule(dsk, keys, **kwargs)
#     601 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniconda3/lib/python3.9/site-packages/distributed/client.py:3052, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3050         should_rejoin = False
#    3051 try:
# -> 3052     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3053 finally:
#    3054     for f in futures.values():
#
# File ~/miniconda3/lib/python3.9/site-packages/distributed/client.py:2226, in Client.gather(self, futures, errors, direct, asynchronous)
#    2224 else:
#    2225     local_worker = None
# -> 2226 return self.sync(
#    2227     self._gather,
#    2228     futures,
#    2229     errors=errors,
#    2230     direct=direct,
#    2231     local_worker=local_worker,
#    2232     asynchronous=asynchronous,
#    2233 )
#
# File ~/miniconda3/lib/python3.9/site-packages/distributed/utils.py:339, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     337     return future
#     338 else:
# --> 339     return sync(
#     340         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     341     )
#
# File ~/miniconda3/lib/python3.9/site-packages/distributed/utils.py:402, in sync(loop, func, callback_timeout, *args, **kwargs)
#     400 else:
#     401     while not e.is_set():
# --> 402         wait(10)
#     404 if error:
#     405     typ, exc, tb = error
#
# File ~/miniconda3/lib/python3.9/site-packages/distributed/utils.py:391, in sync.<locals>.wait(timeout)
#     389 def wait(timeout):
#     390     try:
# --> 391         return e.wait(timeout)
#     392     except KeyboardInterrupt:
#     393         loop.add_callback(cancel)
#
# File ~/miniconda3/lib/python3.9/threading.py:574, in Event.wait(self, timeout)
#     572 signaled = self._flag
#     573 if not signaled:
# --> 574     signaled = self._cond.wait(timeout)
#     575 return signaled
#
# File ~/miniconda3/lib/python3.9/threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# 2022-09-28 15:26:14,389 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2022-09-28 15:26:14,649 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2022-09-28 15:26:15,189 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2022-09-28 15:26:15,793 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2022-09-28 15:26:15,911 - distributed.nanny - WARNING - Restarting worker
# 2022-09-28 15:26:17,631 - distributed.nanny - WARNING - Restarting worker
# 2022-09-28 15:26:18,419 - distributed.nanny - WARNING - Restarting worker
# 2022-09-28 15:26:19,970 - distributed.nanny - WARNING - Restarting worker

# %%
# Now we will resample the data to daily, where the daily values are the mean of the hourly values within that day.
df4.resample('1d').mean()
# Out:
# Dask DataFrame Structure:
#                                 TA SOIL_TEMP
# npartitions=1826
# 2015-01-01 00:00:00+00:00  float64   float64
# 2015-01-02 00:00:00+00:00      ...       ...
# ...                            ...       ...
# 2019-12-31 00:00:00+00:00      ...       ...
# 2020-01-01 00:00:00+00:00      ...       ...
# Dask Name: resample, 15 graph layers

# %%
# %time df4.compute()
# Out:
# 2022-09-28 15:01:30,464 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-09-28 15:01:30,794 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-09-28 15:01:32,786 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2022-09-28 15:01:33,019 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-09-28 15:01:33,457 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-09-28 15:01:34,775 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2022-09-28 15:01:35,882 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2022-09-28 15:01:35,992 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2022-09-28 15:01:36,578 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2022-09-28 15:01:38,099 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2022-09-28 15:01:39,562 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-09-28 15:01:39,822 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-09-28 15:01:40,518 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-09-28 15:01:42,228 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 
- distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:31,555 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:31,629 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:31,729 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:31,836 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:31,961 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:32,029 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:32,146 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:32,231 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:32,328 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:32,509 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:32,529 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:32,637 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:32,747 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:32,827 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:33,005 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:33,028 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:33,133 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:03:33,228 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 1.86 GiB
# ...
#     atexit_call()
#   File "/home/dmckay/miniconda3/lib/python3.9/concurrent/futures/thread.py", line 31, in _python_exit
#     t.join()
#   File "/home/dmckay/miniconda3/lib/python3.9/threading.py", line 1053, in join
#   File "/home/dmckay/miniconda3/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     atexit_call()
#   File "/home/dmckay/miniconda
# KeyboardInterrupt
#
# 3/lib/python3.9/concurrent/futures/thread.py", line 31, in _python_exit
#     self._wait_for_tstate_lock()
#   File "/home/dmckay/miniconda3/lib/python3.9/threading.py", line 1073, in _wait_for_tstate_lock
#     exitcode = _main(fd, parent_sentinel)
#     t.join()
#   File "/home/dmckay/miniconda3/lib/python3.9/multiprocessing/spawn.py", line 129, in _main
#   File "/home/dmckay/miniconda3/lib/python3.9/threading.py", line 1053, in join
#     exitcode = _main(fd, parent_sentinel)
#   File "/home/dmckay/miniconda3/lib/python3.9/multiprocessing/spawn.py", line 129, in _main
#     return self._bootstrap(parent_sentinel)
#   File "/home/dmckay/miniconda3/lib/python3.9/multiprocessing/process.py", line 333, in _bootstrap
#     threading._shutdown()
#   File "/home/dmckay/miniconda3/lib/python3.9/threading.py", line 1440, in _shutdown
#     atexit_call()
#   File "/home/dmckay/miniconda3/lib/python3.9/concurrent/futures/thread.py", line 31, in _python_exit
#     return self._bootstrap(parent_sentinel)
#   File "/home/dmckay/miniconda3/lib/python3.9/multiprocessing/process.py", line 333, in _bootstrap
#     t.join()
#   File "/home/dmckay/miniconda3/lib/python3.9/threading.py", line 1053, in join
#     self._wait_for_tstate_lock()
#   File "/home/dmckay/miniconda3/lib/python3.9/threading.py", line 1073, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
#     threading._shutdown()
#   File "/home/dmckay/miniconda3/lib/python3.9/threading.py", line 1440, in _shutdown
#     atexit_call()
#   File "/home/dmckay/miniconda3/lib/python3.9/concurrent/futures/thread.py", line 31, in _python_exit
#     t.join()
#   File "/home/dmckay/miniconda3/lib/python3.9/threading.py", line 1053, in join
#     self._wait_for_tstate_lock()
#   File "/home/dmckay/miniconda3/lib/python3.9/threading.py", line 1073, in _wait_for_tstate_lock
#     self._wait_for_tstate_lock()
#   File "/home/dmckay/miniconda3/lib/python3.9/threading.py", line 1073, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
# KeyboardInterrupt
# 2022-09-28 15:05:05,143 - distributed.nanny - WARNING - Restarting worker
# 2022-09-28 15:05:05,146 - distributed.nanny - WARNING - Restarting worker
# 2022-09-28 15:05:05,169 - distributed.nanny - WARNING - Restarting worker
# 2022-09-28 15:07:04,970 - distributed.worker_memory - WARNING - gc.collect() took 3.152s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2022-09-28 15:07:05,005 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.46 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:07:05,783 - distributed.worker_memory - WARNING - gc.collect() took 3.135s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2022-09-28 15:07:05,784 - distributed.worker_memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 1.49 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:07:07,618 - distributed.worker_memory - WARNING - gc.collect() took 2.665s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2022-09-28 15:07:08,803 - distributed.worker_memory - WARNING - Worker is at 79% memory usage. Resuming worker. Process memory: 1.48 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:07:15,242 - distributed.worker_memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 1.53 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:07:16,243 - distributed.worker_memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 1.54 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:07:16,247 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.54 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:07:16,270 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.54 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:07:16,438 - distributed.worker_memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 1.54 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:07:16,456 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.54 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:07:26,036 - distributed.worker_memory - WARNING - Worker is at 31% memory usage. Resuming worker. Process memory: 602.49 MiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:07:27,190 - distributed.worker_memory - WARNING - Worker is at 45% memory usage. Resuming worker. Process memory: 863.71 MiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:07:27,537 - distributed.worker_memory - WARNING - Worker is at 33% memory usage. Resuming worker. Process memory: 630.41 MiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:08:18,427 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2022-09-28 15:08:27,417 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-09-28 15:08:28,328 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-09-28 15:08:31,870 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-09-28 15:08:36,593 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-09-28 15:08:38,406 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2022-09-28 15:08:46,963 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2022-09-28 15:08:47,127 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2022-09-28 15:08:47,127 - distributed.worker_memory - WARNING - gc.collect() took 4.647s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2022-09-28 15:08:47,127 - distributed.worker_memory - WARNING - Worker is at 90% memory usage. Pausing worker.  Process memory: 1.69 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:08:48,928 - distributed.worker_memory - WARNING - Worker tcp://127.0.0.1:37939 (pid=1261) exceeded 95% memory budget. Restarting...
# 2022-09-28 15:08:49,294 - distributed.nanny - WARNING - Restarting worker
# 2022-09-28 15:08:52,022 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2022-09-28 15:08:54,740 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-09-28 15:08:57,559 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2022-09-28 15:09:03,625 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2022-09-28 15:09:05,672 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2022-09-28 15:09:10,671 - distributed.worker_memory - WARNING - Worker tcp://127.0.0.1:46495 (pid=1258) exceeded 95% memory budget. Restarting...
# 2022-09-28 15:09:11,005 - distributed.nanny - WARNING - Restarting worker
# 2022-09-28 15:09:17,163 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2022-09-28 15:09:22,495 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:46495
# Traceback (most recent call last):
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/worker.py", line 2029, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/worker.py", line 2818, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/worker.py", line 2798, in _get_data
#     response = await send_recv(
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/dmckay/miniconda3/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:58978 remote=tcp://127.0.0.1:46495>: Stream is closed
# 2022-09-28 15:09:26,899 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-09-28 15:09:26,900 - distributed.worker_memory - WARNING - gc.collect() took 4.325s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2022-09-28 15:09:26,900 - distributed.worker_memory - WARNING - Worker is at 92% memory usage. Pausing worker.  Process memory: 1.72 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:09:27,821 - distributed.worker_memory - WARNING - Worker tcp://127.0.0.1:37055 (pid=1255) exceeded 95% memory budget. Restarting...
# 2022-09-28 15:09:28,185 - distributed.nanny - WARNING - Restarting worker
# 2022-09-28 15:10:30,859 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2022-09-28 15:10:35,427 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2022-09-28 15:10:40,607 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2022-09-28 15:10:46,958 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-09-28 15:10:54,785 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2022-09-28 15:10:59,287 - distributed.worker_memory - WARNING - gc.collect() took 2.333s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2022-09-28 15:10:59,287 - distributed.worker_memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 1.50 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:11:00,285 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2022-09-28 15:11:00,292 - distributed.worker_memory - WARNING - gc.collect() took 1.992s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2022-09-28 15:11:00,293 - distributed.worker_memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 1.51 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:11:01,840 - distributed.worker_memory - WARNING - Worker is at 79% memory usage. Resuming worker. Process memory: 1.49 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:11:01,988 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.47 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:11:01,989 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.47 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:11:11,579 - distributed.worker_memory - WARNING - gc.collect() took 1.489s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2022-09-28 15:11:11,583 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.42 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:11:13,966 - distributed.worker_memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 1.54 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:11:17,766 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2022-09-28 15:11:22,156 - distributed.worker_memory - WARNING - Worker is at 39% memory usage. Resuming worker. Process memory: 761.20 MiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:11:23,949 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2022-09-28 15:11:24,843 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2022-09-28 15:11:25,947 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2022-09-28 15:11:27,228 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2022-09-28 15:11:28,817 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2022-09-28 15:11:29,226 - distributed.worker_memory - WARNING - Worker is at 70% memory usage. Resuming worker. Process memory: 1.31 GiB -- Worker memory limit: 1.86 GiB
# 2022-09-28 15:11:31,423 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
